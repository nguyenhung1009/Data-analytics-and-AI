# %% [markdown]
# # Buổi 02 – Phân tích dữ liệu bán hàng (Sales Data Sample)
#
# **Bộ dữ liệu:** `sales_data_sample.xlsx` – dữ liệu bán hàng của công ty đa quốc gia ABC.
#
# **Mô tả các cột:**
# | Cột | Ý nghĩa |
# |---|---|
# | ORDERNUMBER | Mã hóa đơn |
# | QUANTITYORDERED | Số lượng sản phẩm đặt hàng |
# | ORDERLINENUMBER | Dòng thông tin mua sản phẩm trên hóa đơn |
# | SALES | Giá trị đặt hàng |
# | ORDERDATE | Ngày đặt hàng |
# | STATUS | Trạng thái giao hàng |
# | COUNTRY | Địa điểm đặt hàng |
# | DEALSIZE | Phân loại kích thước đơn hàng (Small/Medium/Large) |
# | Discount | Giảm giá (%) |
# | Profit | Lợi nhuận |
#
# ---
# ## Phần 1: Nhập và khám phá dữ liệu tổng quan

# %% [markdown]
# **Câu 1.** Đọc dữ liệu từ file `sales_data_sample.xlsx` vào DataFrame tên `df`. Hiển thị 5 dòng đầu và 5 dòng cuối của dữ liệu.

# %%
import pandas as pd

df = pd.read_excel('sales_data_sample.xlsx')
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER    SALES  ORDERDATE   STATUS  \
# 0        10107               30                2  2871.00 2003-02-24  Shipped
# 1        10121               34                5  2765.90 2003-05-07  Shipped
# 2        10134               41                2  3884.34 2003-07-01  Shipped
# 3        10145               45                6  3746.70 2003-08-25  Shipped
# 4        10159               49               14  5205.27 2003-10-10  Shipped
#
#   COUNTRY DEALSIZE  Discount    Profit
# 0     USA    Small      0.00   41.9136
# 1  France    Small      0.00  219.5820
# 2  France   Medium      0.00    6.8714
# 3     USA   Medium      0.45 -383.0310
# 4     USA   Medium      0.20    2.5164

# %%
df.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER    SALES  ORDERDATE  \
# 2818        10350               20               15  2244.40 2004-12-02
# 2819        10373               29                1  3978.51 2005-01-31
# 2820        10386               43                4  5417.57 2005-03-01
# 2821        10397               34                1  2116.16 2005-03-28
# 2822        10414               47                9  3079.44 2005-05-06
#
#         STATUS  COUNTRY DEALSIZE  Discount    Profit
# 2818   Shipped    Spain    Small       0.0  315.7404
# 2819   Shipped  Finland   Medium       0.2    2.3520
# 2820  Resolved    Spain   Medium       0.2    7.4694
# 2821   Shipped   France    Small       0.2   22.6782
# 2822   On Hold      USA   Medium       0.2    0.5580

# %% [markdown]
# **Câu 2.** Cho biết DataFrame có bao nhiêu dòng, bao nhiêu cột? Kiểu dữ liệu (dtype) của từng cột là gì?

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (2823, 10)
# ORDERNUMBER                 int64
# QUANTITYORDERED             int64
# ORDERLINENUMBER             int64
# SALES                     float64
# ORDERDATE          datetime64[us]
# STATUS                        str
# COUNTRY                       str
# DEALSIZE                      str
# Discount                  float64
# Profit                    float64
# dtype: object

# %% [markdown]
# **Câu 3.** Kiểm tra xem dữ liệu có giá trị thiếu (missing values) ở cột nào không? Có dòng nào bị trùng lặp hoàn toàn (duplicate) không?

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER        0
# QUANTITYORDERED    0
# ORDERLINENUMBER    0
# SALES              0
# ORDERDATE          0
# STATUS             0
# COUNTRY            0
# DEALSIZE           0
# Discount           0
# Profit             0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# **Câu 4.** Sử dụng `describe()` để xem thống kê mô tả (min, max, mean, std...) cho các cột số: `QUANTITYORDERED`, `SALES`, `Discount`, `Profit`. Nhận xét ngắn gọn về khoảng giá trị của `Discount` và `Profit`.

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER         SALES  \
# count   2823.000000      2823.000000      2823.000000   2823.000000
# mean   10258.725115        35.092809         6.466171   3553.889072
# min    10100.000000         6.000000         1.000000    482.130000
# 25%    10180.000000        27.000000         3.000000   2203.430000
# 50%    10262.000000        35.000000         6.000000   3184.800000
# 75%    10333.500000        43.000000         9.000000   4508.000000
# max    10425.000000        97.000000        18.000000  14082.800000
# std       92.085478         9.741443         4.225841   1841.865106
#
#                         ORDERDATE     Discount       Profit
# count                        2823  2823.000000  2823.000000
# mean   2004-05-11 00:16:49.989373     0.152710    25.383894
# min           2003-01-06 00:00:00     0.000000 -3839.990400
# 25%           2003-11-06 12:00:00     0.000000     1.801600
# 50%           2004-06-15 00:00:00     0.150000     8.880000
# 75%           2004-11-17 12:00:00     0.200000    30.488300
# max           2005-05-31 00:00:00     0.800000  3919.988800
# std                           NaN     0.203333   192.452771

# %%
df[['QUANTITYORDERED','SALES', 'Discount', 'Profit']]
# Out:
#       QUANTITYORDERED    SALES  Discount    Profit
# 0                  30  2871.00      0.00   41.9136
# 1                  34  2765.90      0.00  219.5820
# 2                  41  3884.34      0.00    6.8714
# 3                  45  3746.70      0.45 -383.0310
# 4                  49  5205.27      0.20    2.5164
# ...               ...      ...       ...       ...
# 2818               20  2244.40      0.00  315.7404
# 2819               29  3978.51      0.20    2.3520
# 2820               43  5417.57      0.20    7.4694
# 2821               34  2116.16      0.20   22.6782
# 2822               47  3079.44      0.20    0.5580
#
# [2823 rows x 4 columns]

# %% [markdown]
# **Câu 5.** Dữ liệu có bao nhiêu quốc gia (COUNTRY) khác nhau? Liệt kê tên các quốc gia đó. Có bao nhiêu giá trị khác nhau trong cột `STATUS` và `DEALSIZE`? Đó là những giá trị nào?

# %%
df['COUNTRY'].unique()
#len.df['COUNTRY'].unique()
# Out:
# <StringArray>
# [        'USA',      'France',      'Norway',   'Australia',     'Finland',
#      'Austria',          'UK',       'Spain',      'Sweden',   'Singapore',
#       'Canada',       'Japan',       'Italy',     'Denmark',     'Belgium',
#  'Philippines',     'Germany', 'Switzerland',     'Ireland']
# Length: 19, dtype: str

# %%
df['COUNTRY'].nunique()
# Out:
# 19

# %% [markdown]
# ---
# ## Phần 2: Lọc và sắp xếp dữ liệu

# %% [markdown]
# **Câu 6.** Lọc ra các đơn hàng có `SALES` lớn hơn 5000. Có bao nhiêu đơn hàng thỏa điều kiện này?

# %%
df[(df['SALES'] > 5000) & (df['SALES'] < 8000)]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER    SALES  ORDERDATE  \
# 4           10159               49               14  5205.27 2003-10-10
# 7           10188               48                1  5512.32 2003-11-18
# 20          10341               41                9  7737.93 2004-11-24
# 25          10417               66                2  7516.08 2005-05-13
# 26          10103               26               11  5404.62 2003-01-29
# ...           ...              ...              ...      ...        ...
# 2685        10361               44               10  5001.92 2004-12-17
# 2686        10375               44               11  5208.72 2005-02-03
# 2689        10401               77                9  7084.00 2005-04-03
# 2715        10397               48                3  5192.64 2005-03-28
# 2820        10386               43                4  5417.57 2005-03-01
#
#         STATUS    COUNTRY DEALSIZE  Discount   Profit
# 4      Shipped        USA   Medium       0.2   2.5164
# 7      Shipped     Norway   Medium       0.2  90.7152
# 20     Shipped    Austria    Large       0.2   7.3840
# 25    Disputed      Spain    Large       0.2   4.2224
# 26     Shipped     Norway   Medium       0.0  11.7741
# ...        ...        ...      ...       ...      ...
# 2685   Shipped  Australia   Medium       0.2  29.9850
# 2686   Shipped     France   Medium       0.7  -2.4564
# 2689   On Hold        USA    Large       0.2   1.6400
# 2715   Shipped     France   Medium       0.0  62.3904
# 2820  Resolved      Spain   Medium       0.2   7.4694
#
# [470 rows x 10 columns]

# %% [markdown]
# **Câu 7.** Lọc ra các đơn hàng thuộc quốc gia `USA` và có `DEALSIZE` là `Large`. Sắp xếp kết quả theo `SALES` giảm dần và hiển thị 10 dòng đầu tiên.

# %%
result = df[(df['COUNTRY'] == 'USA') & (df['DEALSIZE'] == 'Large')]

result = result.sort_values(by='SALES', ascending=False)

result.head(10)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER     SALES  ORDERDATE  \
# 598         10407               76                2  14082.80 2005-04-22
# 744         10322               50                6  12536.50 2004-11-04
# 44          10312               48                3  11623.70 2004-10-21
# 1133        10333               46                2  11336.70 2004-11-18
# 188         10127               46                2  11279.20 2003-06-03
# 2505        10388               46                2  10066.60 2005-03-03
# 131         10400               64                9   9661.44 2005-04-01
# 175         10276               50                3   9631.00 2004-08-02
# 319         10142               46               11   9470.94 2003-08-08
# 164         10147               48                7   9245.76 2003-09-05
#
#        STATUS COUNTRY DEALSIZE  Discount    Profit
# 598   On Hold     USA    Large       0.2    1.0178
# 744   Shipped     USA    Large       0.2    1.6762
# 44    Shipped     USA    Large       0.0   19.7714
# 1133  Shipped     USA    Large       0.2  -23.3640
# 188   Shipped     USA    Large       0.2    6.2550
# 2505  Shipped     USA    Large       0.0  327.5060
# 131   Shipped     USA    Large       0.2   29.3640
# 175   Shipped     USA    Large       0.2    6.5520
# 319   Shipped     USA    Large       0.0   80.0226
# 164   Shipped     USA    Large       0.2    2.7324

# %% [markdown]
# **Câu 8.** Lọc ra các đơn hàng có `Profit` âm (lỗ). Các đơn hàng này thường rơi vào `STATUS` nào? `DEALSIZE` nào? (Gợi ý: dùng `value_counts()`)

# %%
df_prodit = df[df['Profit'] < 0]
print("status: ", df_prodit['STATUS'].value_counts())
print("dealsize: ", df_prodit['DEALSIZE'].value_counts())
# Out:
# status:  STATUS
# Shipped       454
# In Process     14
# Cancelled      14
# On Hold        10
# Resolved        7
# Disputed        3
# Name: count, dtype: int64
# dealsize:  DEALSIZE
# Medium    241
# Small     228
# Large      33
# Name: count, dtype: int64

# %% [markdown]
# **Câu 9.** Lọc ra các đơn hàng có mức giảm giá (`Discount`) từ 0.3 trở lên. Doanh số (`SALES`) trung bình của nhóm này là bao nhiêu, so với doanh số trung bình toàn bộ dữ liệu?

# %%
df_discount = df[df['Discount'] >= 0.3]
print("Doanh số trung bình của nhóm: ", df_discount['SALES'].mean())
print("Doanh số trung bình toàn bộ dữ liệu: ", df['SALES'].mean())
# Out:
# Doanh số trung bình của nhóm:  3590.8555091383814
# Doanh số trung bình toàn bộ dữ liệu:  3553.889071909316

# %% [markdown]
# ---
# ## Phần 3: Tạo cột mới và biến đổi dữ liệu

# %% [markdown]
# **Câu 10.** Từ cột `ORDERDATE`, tạo thêm 3 cột mới: `ORDER_YEAR`, `ORDER_MONTH`, `ORDER_QUARTER` chứa năm, tháng, quý của ngày đặt hàng.

# %%
df['ORDER_YEAR'] = df['ORDERDATE'].dt.year
df['ORDER_MONTH'] = df['ORDERDATE'].dt.month
df['ORDER_QUARTER'] = df['ORDERDATE'].dt.quarter

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER    SALES  ORDERDATE  \
# 0           10107               30                2  2871.00 2003-02-24
# 1           10121               34                5  2765.90 2003-05-07
# 2           10134               41                2  3884.34 2003-07-01
# 3           10145               45                6  3746.70 2003-08-25
# 4           10159               49               14  5205.27 2003-10-10
# ...           ...              ...              ...      ...        ...
# 2818        10350               20               15  2244.40 2004-12-02
# 2819        10373               29                1  3978.51 2005-01-31
# 2820        10386               43                4  5417.57 2005-03-01
# 2821        10397               34                1  2116.16 2005-03-28
# 2822        10414               47                9  3079.44 2005-05-06
#
#         STATUS  COUNTRY DEALSIZE  Discount    Profit  ORDER_YEAR  ORDER_MONTH  \
# 0      Shipped      USA    Small      0.00   41.9136        2003            2
# 1      Shipped   France    Small      0.00  219.5820        2003            5
# 2      Shipped   France   Medium      0.00    6.8714        2003            7
# 3      Shipped      USA   Medium      0.45 -383.0310        2003            8
# 4      Shipped      USA   Medium      0.20    2.5164        2003           10
# ...        ...      ...      ...       ...       ...         ...          ...
# 2818   Shipped    Spain    Small      0.00  315.7404        2004           12
# 2819   Shipped  Finland   Medium      0.20    2.3520        2005            1
# 2820  Resolved    Spain   Medium      0.20    7.4694        2005            3
# 2821   Shipped   France    Small      0.20   22.6782        2005            3
# 2822   On Hold      USA   Medium      0.20    0.5580        2005            5
#
#       ORDER_QUARTER
# 0                 1
# 1                 2
# 2                 3
# 3                 3
# 4                 4
# ...             ...
# 2818              4
# 2819              1
# 2820              1
# 2821              1
# 2822              2
#
# [2823 rows x 13 columns]

# %% [markdown]
# **Câu 11.** Tạo cột mới `PROFIT_MARGIN` = `Profit` / `SALES` (tỷ suất lợi nhuận). Đơn hàng nào có tỷ suất lợi nhuận cao nhất? Thấp nhất?

# %%
df['PROFIT_MARGIN'] = df['Profit'] / df['SALES']

# %%
print(df['PROFIT_MARGIN'].min())
print(df['PROFIT_MARGIN'].max())
# Out:
# -2.5657408595253357
# 1.2942766250376778

# %% [markdown]
# **Câu 12.** Tạo cột `NET_SALES` = `SALES` * (1 - `Discount`) thể hiện doanh số sau khi trừ giảm giá. So sánh tổng `SALES` và tổng `NET_SALES` của toàn bộ dữ liệu.

# %%
df['NET_SALES'] = df['SALES'] * (1 - df['Discount'])
print("Tổng sales: ", df["SALES"].sum())
print("Tổng net_sales: ", df['NET_SALES'].sum())
# Out:
# Tổng sales:  10032628.85
# Tổng net_sales:  8470955.407699998

# %% [markdown]
# ---
# ## Phần 4: Nhóm dữ liệu (Groupby) và tổng hợp

# %% [markdown]
# **Câu 13.** Tính tổng `SALES` và tổng `Profit` theo từng `COUNTRY`. Sắp xếp giảm dần theo tổng `SALES` và cho biết Top 5 quốc gia có doanh số cao nhất.

# %%
df.groupby(by='COUNTRY')['SALES'].sum()
# Out:
# COUNTRY
# Australia       630623.10
# Austria         202062.53
# Belgium         108412.62
# Canada          224078.56
# Denmark         245637.15
# Finland         329581.91
# France         1110916.52
# Germany         220472.09
# Ireland          57756.43
# Italy           374674.31
# Japan           188167.81
# Norway          307463.70
# Philippines      94015.73
# Singapore       288488.41
# Spain          1215686.92
# Sweden          210014.21
# Switzerland     117713.56
# UK              478880.46
# USA            3627982.83
# Name: SALES, dtype: float64

# %% [markdown]
# **Câu 14.** Tính `SALES` trung bình và `Profit` trung bình theo từng nhóm `DEALSIZE`. Nhận xét: nhóm `Large` có thực sự mang lại lợi nhuận trung bình cao nhất không?

# %%
df.groupby(by='DEALSIZE')[['SALES', 'Profit']].mean()
# Out:
#                 SALES     Profit
# DEALSIZE
# Large     8293.753248   8.481640
# Medium    4398.433699  28.543171
# Small     2061.682800  24.043187

# %% [markdown]
# **Câu 15.** Tính số lượng đơn hàng (đếm số `ORDERNUMBER` duy nhất) theo từng `STATUS`. Tỷ lệ đơn hàng bị `Cancelled` hoặc `Disputed` chiếm bao nhiêu % tổng số đơn hàng?

# %%
df.groupby(by='STATUS')['ORDERNUMBER'].nunique()
total_orders = df['ORDERNUMBER'].nunique()
cancelled_disputed =  df[df['STATUS'].isin(['Cancelled', 'Disputed'])]['ORDERNUMBER'].nunique()
percentage = cancelled_disputed / total_orders * 100

print("Tổng số đơn hàng:", total_orders)
print("Số đơn Cancelled hoặc Disputed:", cancelled_disputed)
print("Tỷ lệ:", percentage, "%")
# Out:
# Tổng số đơn hàng: 307
# Số đơn Cancelled hoặc Disputed: 7
# Tỷ lệ: 2.2801302931596092 %

# %% [markdown]
# **Câu 16.** Sử dụng `pivot_table` để tạo bảng tổng hợp tổng `SALES` theo `COUNTRY` (hàng) và `DEALSIZE` (cột).

# %%
pivot_sales = pd.pivot_table(
    df,
    values='SALES',
    index='COUNTRY',
    columns='DEALSIZE',
    aggfunc='sum'
)

print(pivot_sales)
# Out:
# DEALSIZE         Large      Medium      Small
# COUNTRY
# Australia     60252.04   381245.00  189126.06
# Austria       32792.08   125314.10   43956.35
# Belgium            NaN    71531.37   36881.25
# Canada         9064.89   137430.48   77583.19
# Denmark       49886.67   140050.70   55699.78
# Finland       40012.32   201741.96   87827.63
# France       179004.87   643606.22  288305.43
# Germany       30496.06   133151.79   56824.24
# Ireland       15439.44    26822.87   15494.12
# Italy         57565.43   184133.88  132975.00
# Japan         25470.16   101097.22   61600.43
# Norway        41042.70   190502.23   75918.77
# Philippines    7483.98    62415.84   24115.91
# Singapore     35363.19   178562.94   74562.28
# Spain        141042.51   757927.09  316717.32
# Sweden        14345.30   143685.97   51982.94
# Switzerland        NaN    98617.40   19096.16
# UK            35155.24   301233.02  142492.20
# USA          527702.38  2208362.16  891918.29

# %% [markdown]
# **Câu 17.** Theo `ORDER_YEAR` đã tạo ở Câu 10, tính tổng doanh số (`SALES`) theo từng năm. Doanh số năm nào cao nhất? Lưu ý gì về dữ liệu năm 2005 (dữ liệu có đủ 12 tháng không)?

# %%
sales_by_year = df.groupby('ORDER_YEAR')['SALES'].sum()
print(sales_by_year)

print("Năm có doanh số cao nhất:", sales_by_year.idxmax())
print("Doanh số cao nhất:", sales_by_year.max())
df[df['ORDER_YEAR'] == 2005]['ORDER_MONTH'].value_counts().sort_index()
# Out:
# ORDER_YEAR
# 2003    3516979.54
# 2004    4724162.60
# 2005    1791486.71
# Name: SALES, dtype: float64
# Năm có doanh số cao nhất: 2004
# Doanh số cao nhất: 4724162.6
# ORDER_MONTH
# 1     99
# 2     97
# 3    106
# 4     56
# 5    120
# Name: count, dtype: int64

# %% [markdown]
# ---
# ## Phần 6: Câu hỏi tổng hợp / thảo luận

# %% [markdown]
# **Câu 22.** Từ những phân tích trên, hãy viết một đoạn nhận xét ngắn (5–7 dòng) về:
# - Quốc gia nào đang mang lại doanh số/lợi nhuận tốt nhất cho công ty ABC?
# - Nhóm `DEALSIZE` nào hiệu quả nhất?
# - Có rủi ro nào đáng lưu ý (ví dụ: đơn hàng lỗ, tỷ lệ hủy/tranh chấp cao) không?
# - Đề xuất 1–2 hành động công ty nên cân nhắc.

# %% [markdown]
# ### 📊 Nhận xét kết quả phân tích
#
# - **Thị trường:** USA là quốc gia mang lại **doanh số và lợi nhuận cao nhất**, nên đây là thị trường quan trọng cần được ưu tiên.
#
# - **Quy mô đơn hàng:** Nhóm **DEALSIZE Medium** có hiệu quả nổi bật và đóng góp lớn vào tổng doanh số.
#
# - **Rủi ro:** Vẫn xuất hiện một số đơn hàng có **Profit âm**. Ngoài ra, các đơn hàng có trạng thái **Cancelled** hoặc **Disputed** cũng cần được theo dõi.
#
# - **Đề xuất:** Công ty nên tiếp tục tập trung vào thị trường **USA** và nhóm đơn hàng **Medium**, đồng thời kiểm soát chính sách giảm giá và tìm nguyên nhân các đơn hàng bị lỗ, hủy hoặc tranh chấp.
